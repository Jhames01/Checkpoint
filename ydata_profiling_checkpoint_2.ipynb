# %% [markdown]
# <a href="https://colab.research.google.com/github/Jhames01/Checkpoint/blob/master/ydata_profiling_checkpoint_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Instructions
#
# Part 1: Data Exploration with Pandas
# Load the provided dataset into a pandas dataframe
# Use pandas to explore the dataset. For example, you might start by using the head() and info() methods to get an overview of the data.
# Look for missing values in the dataset. You can use the isnull() method to identify missing values.
# Use pandas to calculate some summary statistics for the dataset. For example, you might use the describe() method to get summary statistics for the numerical columns in the dataset.
# Part 2: Data Exploration with ydata-Profiling
# Use ydata-profiling to generate a report of the provided dataset.
# Look for missing values in the dataset. You can use the report generated by ydata-profiling to identify missing values.
# Look for correlations between different columns in the dataset. You can use the report generated by ydata-profiling to identify correlations between different columns.
# Identify any outliers or unusual values in the dataset. You can use the report generated by ydata-profiling to identify any outliers or unusual values.

# %%
# Use ydata-profiling to generate a report of the provided dataset
import pandas as pd
Tunisair_flights_dataset_df = pd.read_csv('/content/Tunisair_flights_dataset.csv')
Tunisair_flights_dataset_df
# Out:
#        Filght_date  Flight_ID Departure point Arrival point  \
# 0       2016-01-03   TU 0712              CMN           TUN
# 1       2016-01-13   TU 0757              MXP           TUN
# 2       2016-01-16   TU 0214              TUN           IST
# 3       2016-01-17   TU 0480              DJE           NTE
# 4       2016-01-17   TU 0338              TUN           ALG
# ...            ...        ...             ...           ...
# 107828  2018-07-05  WKL 0000              TUN           TUN
# 107829  2018-01-13   UG 0003              DJE           TUN
# 107830  2018-11-07  SGT 0000              TUN           TUN
# 107831  2018-01-23   UG 0010              TUN           DJE
# 107832  2018-11-13   UG 0002              TUN           DJE
#
#        Scheduled_departure_time Scheduled_arrival_time STATUS Aircraft_code  \
# 0           2016-01-03 10:30:00    2016-01-03 12.55.00    ATA     TU 32AIMN
# 1           2016-01-13 15:05:00    2016-01-13 16.55.00    ATA     TU 31BIMO
# ...

# %%
# Look for missing values in the dataset. You can use the isnull() method to identify missing values.
missing_values = Tunisair_flights_dataset_df.isnull() # Changed df to Tunisair_flights_dataset_df
print(missing_values)
# Out:
#         Filght_date  Flight_ID  Departure point  Arrival point  \
# 0             False      False            False          False
# 1             False      False            False          False
# 2             False      False            False          False
# 3             False      False            False          False
# 4             False      False            False          False
# ...             ...        ...              ...            ...
# 107828        False      False            False          False
# 107829        False      False            False          False
# 107830        False      False            False          False
# 107831        False      False            False          False
# 107832        False      False            False          False
#
#         Scheduled_departure_time  Scheduled_arrival_time  STATUS  \
# 0                          False                   False   False
# 1                          False                   False   False
# ...

# %%
# Look for missing values in the dataset. You can use the isnull() method to identify missing values.
numerical_summary = Tunisair_flights_dataset_df.describe()
print("Numerical Summary Statistics:")
print(numerical_summary)
# Out:
# Numerical Summary Statistics:
#        Arrival delay
# count  107833.000000
# mean       48.733013
# std       117.135562
# min         0.000000
# 25%         0.000000
# 50%        14.000000
# 75%        43.000000
# max      3451.000000

# %%
# !pip install ydata-profiling

# %%
import pandas as pd
from ydata_profiling import ProfileReport
import pandas as pd
from ydata_profiling import ProfileReport

# Load your dataset
df = pd.read_csv('/content/Tunisair_flights_dataset.csv')

# Generate a profile report
profile = ProfileReport(df, title='Pandas Profiling Report', explorative=True)

# Save the report to an HTML file
profile.to_file("dataset_report.html")

profile = ProfileReport(df, title='Pandas Profiling Report', explorative=True)

# Save the report to an HTML file
profile.to_file("dataset_report.html")
# Out:
# ...
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
# Look for correlations between different columns in the dataset. You can use the report generated by ydata-profiling to identify correlations between different columns.

import pandas as pd
from ydata_profiling import ProfileReport

# Load your dataset. Change 'your_dataset.csv' to the actual file name,
#  e.g., 'Tunisair_flights_dataset.csv'
df = pd.read_csv('/content/Tunisair_flights_dataset.csv') # Updated file path

# Generate a profile report
profile = ProfileReport(df, title='Pandas Profiling Report', explorative=True)

# Save the report to an HTML file
profile.to_file("dataset_report.html")
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
# Identify any outliers or unusual values in the dataset. You can use the report generated by ydata-profiling to identify any outliers or unusual values
import pandas as pd
from ydata_profiling import ProfileReport

# Load your dataset. Replace 'Tunisair_flights_dataset.csv' if your dataset has a different name.
df = pd.read_csv('/content/Tunisair_flights_dataset.csv')  # Changed 'your_dataset.csv' to 'Tunisair_flights_dataset.csv'

# Generate a profile report
profile = ProfileReport(df, title='Pandas Profiling Report', explorative=True)

# Save the report to an HTML file
profile.to_file("dataset_report.html")
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
